# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 3.4.3

# %%
import dlib

# %%
print(dlib.__version__)
# Out:
# 19.22.0

# %%
import matplotlib

# %%
import seaborn

# %%
import matplotlib.pyplot as plt

# %%
imagem = cv2.imread("imagens/20251227_090449.jpg")

# %%
plt.imshow(imagem)

# %%
imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagem_rgb)

# %%
imagem_rgb.shape
# Out:
# (4000, 2252, 3)

# %%
imagem_gray = cv2.cvtColor(imagem_rgb, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(imagem_gray, cmap="gray")

# %%
imagem_gray.shape
# Out:
# (4000, 2252)

# %%
imagem_roi = imagem_rgb[1000:1500, 500:900]
plt.imshow(imagem_roi)

# %%
imagem_roi = cv2.cvtColor(imagem_roi, cv2.COLOR_RGB2BGR)

# %%
cv2.imwrite("image_roi.png", imagem_roi)
# Out:
# True
